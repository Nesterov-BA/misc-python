# %%
import pandas as pd
import numpy as np

# %%
with open('packages.log', 'r') as file1:
    content1 = file1.read().splitlines()
with open('packagesMi.log', 'r') as file2:
    content2 = file2.read().splitlines()
    # print(content2)

# %%
for i in range(len(content1)):
    content1[i] = content1[i].split(' ')[0]
    # print(item)
# print(content1)
for i in range(len(content2)):
    content2[i] = content2[i].split(' ')[0]
    # print(item)
print(set(content2) - set(content1))
print(set(content1) - set(content2))
# Out:
# {'texlive-langjapanese', 'python-nose', 'qt5-virtualkeyboard', 'nvidia-utils', 'texlive-langother', 'qt5-speech', 'intel-ucode', 'nwg-look', 'linux-cachyos-nvidia', 'texlive-langfrench', 'qt5-xmlpatterns', 'qt5-script', 'transmission-remote-gtk', 'texlive-langchinese', 'vlc-gui-skins2', 'texlive-langgerman', 'shfmt', 'jellyfin-media-player', 'qt5-sensors', 'lib32-vulkan-intel', 'python-pytest', 'opencl-nvidia', 'texlive-langenglish', 'texlive-langcjk', 'texlab', 'qt5-multimedia', 'rmpc', 'selectdefaultapplication-fork-git', 'xclip', 'emacs', 'hypridle', 'gnu-free-fonts', 'kdeconnect', 'perl-image-exiftool', 'texlive-langarabic', 'tex-fmt', 'tmux', 'texlive-langportuguese', 'adobe-source-han-sans-cn-fonts', 'powertop', 'libva-nvidia-driver', 'qt5-imageformats', 'jupyterlab', 'localsend', 'nvidia-prime', 'qt5-networkauth', 'texlive-mathscience', 'texlive-langkorean', 'python-isort', 'texlive-langgreek', 'perl-file-homedir', 'vulkan-intel', 'switcheroo-control', 'qt5-webengine', 'qt5-qu
# ...
